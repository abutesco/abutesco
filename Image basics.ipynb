# %% [markdown]
# # Image Basics

# %% [markdown]
# Import required statements

# %%
import numpy as np
import skimage.io as io
import skimage.viewer
import matplotlib.pyplot as plt
import ipympl
# Out:
# /opt/anaconda3/lib/python3.9/site-packages/skimage/viewer/utils/__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *

# %% [markdown]
#  Load Image

# %%
# %matplotlib widget

# %%
image = skimage.io.imread(fname="eight.tiff")
plt.imshow(image)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
print(image.shape)
print(image)
# Out:
# (760, 455, 4)
# [[[178 178 179 255]
#   [  0   0   0 255]
#   [  0   0   0 255]
#   ...
#   [  1   0   0 255]
#   [  1   0   1 255]
#   [  0   0   0 255]]
#
#  [[193 193 193 255]
#   [  0   0   0 255]
#   [  2   0   3 255]
#   ...
#   [ 46   4  60 255]
#   [ 46   5  60 255]
#   [ 46   3  59 255]]
#
#  [[199 198 199 255]
#   [  0   0   0 255]
#   [  5   0   6 255]
#   ...
#   [ 61   7  78 255]
#   [ 60   7  79 255]
#   [ 61   7  79 255]]
#
#  ...
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   0   1 255]
#   ...
#   [  1   0   1 255]
#   [  2   1   1 255]
#   [  1   0   0 255]]
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   1   0 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   1 255]
#   [  0   0   0 255]]
#
#  [[237 237 238 255]
#   [190 189 189 255]
#   [191 190 189 255]
#   ...
#   [211 212 212 255]
#   [213 212 212 255]
#   [212 213 212 255]]]

# %%
zero = skimage.io.imread(fname="eight.tiff")
zero[400,200]= 1.0

fig, ax = plt.subplots()
plt.imshow(zero)
print(zero)
# Out:
# [[[178 178 179 255]
#   [  0   0   0 255]
#   [  0   0   0 255]
#   ...
#   [  1   0   0 255]
#   [  1   0   1 255]
#   [  0   0   0 255]]
#
#  [[193 193 193 255]
#   [  0   0   0 255]
#   [  2   0   3 255]
#   ...
#   [ 46   4  60 255]
#   [ 46   5  60 255]
#   [ 46   3  59 255]]
#
#  [[199 198 199 255]
#   [  0   0   0 255]
#   [  5   0   6 255]
#   ...
#   [ 61   7  78 255]
#   [ 60   7  79 255]
#   [ 61   7  79 255]]
#
#  ...
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   0   1 255]
#   ...
#   [  1   0   1 255]
#   [  2   1   1 255]
#   [  1   0   0 255]]
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   1   0 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   1 255]
#   [  0   0   0 255]]
#
#  [[237 237 238 255]
#   [190 189 189 255]
#   [191 190 189 255]
#   ...
#   [211 212 212 255]
#   [213 212 212 255]
#   [212 213 212 255]]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
io.imshow(five)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/97/567hjmcn6d74v14315cgvdrh0000gn/T/ipykernel_1478/3821572718.py in <module>
# ----> 1 io.imshow(five)
#       2 plt.show()
#
# NameError: name 'io' is not defined

# %%
five = skimage.io.imread(fname="eight.tiff")
five[100,200]= 1.0
five[300,0]= 1.0
fig, ax = plt.subplots()
plt.imshow(five)
print(five)
# Out:
# [[[178 178 179 255]
#   [  0   0   0 255]
#   [  0   0   0 255]
#   ...
#   [  1   0   0 255]
#   [  1   0   1 255]
#   [  0   0   0 255]]
#
#  [[193 193 193 255]
#   [  0   0   0 255]
#   [  2   0   3 255]
#   ...
#   [ 46   4  60 255]
#   [ 46   5  60 255]
#   [ 46   3  59 255]]
#
#  [[199 198 199 255]
#   [  0   0   0 255]
#   [  5   0   6 255]
#   ...
#   [ 61   7  78 255]
#   [ 60   7  79 255]
#   [ 61   7  79 255]]
#
#  ...
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   0   1 255]
#   ...
#   [  1   0   1 255]
#   [  2   1   1 255]
#   [  1   0   0 255]]
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   1   0 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   1 255]
#   [  0   0   0 255]]
#
#  [[237 237 238 255]
#   [190 189 189 255]
#   [191 190 189 255]
#   ...
#   [211 212 212 255]
#   [213 212 212 255]
#   [212 213 212 255]]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
io.imshow(five)
plt.show()
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#make a copy of eight
three_colors = skimage.io.imread(fname="eight.tiff")

#multiply the whole matrix by 128
#three_colors = three_colors * 128

# set the middle row (index 2) to the value of 255., so you end up with the values 0.,128.,and 255
three_colors[200,:] = 255.
three_colors[210,:] = 255.
three_colors[220,:] = 255.
three_colors[230,:] = 255.
three_colors[240,:] = 255.
three_colors[250,:] = 255.
three_colors[2,:] = 255.
fig, ax = plt.subplots()
plt.imshow(three_colors)
print(three_colors)
# Out:
# [[[178 178 179 255]
#   [  0   0   0 255]
#   [  0   0   0 255]
#   ...
#   [  1   0   0 255]
#   [  1   0   1 255]
#   [  0   0   0 255]]
#
#  [[193 193 193 255]
#   [  0   0   0 255]
#   [  2   0   3 255]
#   ...
#   [ 46   4  60 255]
#   [ 46   5  60 255]
#   [ 46   3  59 255]]
#
#  [[255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]
#   ...
#   [255 255 255 255]
#   [255 255 255 255]
#   [255 255 255 255]]
#
#  ...
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   0   1 255]
#   ...
#   [  1   0   1 255]
#   [  2   1   1 255]
#   [  1   0   0 255]]
#
#  [[178 178 178 255]
#   [  0   0   0 255]
#   [  0   1   0 255]
#   ...
#   [  0   0   0 255]
#   [  0   0   1 255]
#   [  0   0   0 255]]
#
#  [[237 237 238 255]
#   [190 189 189 255]
#   [191 190 189 255]
#   ...
#   [211 212 212 255]
#   [213 212 212 255]
#   [212 213 212 255]]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
fig, ax = plt.subplots()
plt.imshow(three_colors,cmap=plt.cm.gray)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
#set the random seed so we all get the same matrix
pseudorandomizer = np.random.RandomState(2021)
#create a 4 X 4 checkerboard of random colors
checkerboard = pseudorandomizer.randint(0,255,size=(4,4,3)
                                       )
#restore the default map as you show the image
fig, ax = plt.subplots()
plt.imshow(checkerboard)
#display the arrays
print(checkerboard)
# Out:
# [[[116  85  57]
#   [128 109  94]
#   [214  44  62]
#   [219 157  21]]
#
#  [[ 93 152 140]
#   [246 198 102]
#   [ 70  33 101]
#   [  7   1 110]]
#
#  [[225 124 229]
#   [154 194 176]
#   [227  63  49]
#   [144 178  54]]
#
#  [[123 180  93]
#   [120   5  49]
#   [166 234 142]
#   [ 71  85  70]]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# extract all the color information for the blue square
upper_right_square = checkerboard[1,3,:]
upper_right_square
# Out:
# array([  7,   1, 110])

# %%
checkerboard[0, 3] = [0, 0 , 0]
plt.imshow(checkerboard)

#plt.show()
print(checkerboard)
# Out:
# [[[116  85  57]
#   [128 109  94]
#   [214  44  62]
#   [  0   0   0]]
#
#  [[ 93 152 140]
#   [246 198 102]
#   [ 70  33 101]
#   [  7   1 110]]
#
#  [[225 124 229]
#   [154 194 176]
#   [227  63  49]
#   [144 178  54]]
#
#  [[123 180  93]
#   [120   5  49]
#   [166 234 142]
#   [ 71  85  70]]]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
